# %% [markdown]
# # LetsGrowMore
# # Image to Pencil Sketch with Python
# # Harshal Shivaji Holam

# %% [markdown]
# Import important libraries

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %% [markdown]
# Import image

# %%
image = cv2.imread(r'Downloads\abc.jpg')
# cv2.imshow("Original Image", image)
# cv2.waitKey(0)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=800x484 at 0x1E3292E87F0>

# %% [markdown]
# Gray image

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=800x484 at 0x1E329AB7100>

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=800x484 at 0x1E329AB7520>

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=800x484 at 0x1E3299F0A30>

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=800x484 at 0x1E3299F0EB0>
